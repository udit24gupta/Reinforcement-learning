# %% [markdown]
# <a href="https://colab.research.google.com/github/udit24gupta/Reinforcement-learning/blob/main/Rl_corelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.array([1,2,3,4])
Y = np.array([4,5,6,7])
r = np.corrcoef(X,Y)
plt.scatter(X,Y)
plt.show()
print(r)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.array([4,5,6,7])
Y = np.array([7,6,5,4])
r = np.corrcoef(X,Y)
plt.scatter(X,Y)
plt.show()
print(r)
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.array([0,0])
Y = np.array([0,0])
r = np.corrcoef(X,Y)
plt.scatter(X,Y)
plt.show()
print(r)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2829: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# [[nan nan]
#  [nan nan]]
